# %%
import matplotlib.pyplot as plt

epochs = list(range(0, 481, 20))
loss = [
    57.86, 71.10, 64.19, 54.65, 62.92, 47.24, 52.20, 53.59, 47.90, 101.51,
    70.26, 69.42, 38.65, 29.30, 126.05, 57.37, 57.75, 45.52, 45.84, 66.39,
    61.14, 43.35, 55.76, 52.79, 62.33
]
pred_std = [
    2.49, 5.24, 2.04, 2.11, 4.80, 4.12, 2.72, 2.46, 1.91, 6.11,
    4.79, 3.89, 0.00, 0.00, 8.71, 0.97, 0.57, 0.00, 0.58, 0.58,
    0.70, 0.01, 0.03, 0.61, 0.57
]
y_std = [
    7.33, 7.40, 7.42, 6.95, 6.49, 6.12, 6.61, 6.23, 6.18, 7.69,
    6.88, 6.77, 5.76, 5.01, 7.05, 7.05, 7.08, 6.14, 6.24, 7.46,
    7.19, 6.14, 6.84, 6.63, 7.40
]

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(8, 6), sharex=True)

ax1.plot(epochs, loss, marker='o')
ax1.set_ylabel("Loss")
ax1.set_title("Training Metrics (")

ax2.plot(epochs, pred_std, marker='o', label="pred_std")
ax2.plot(epochs, y_std, marker='o', label="y_std")
ax2.set_xlabel("Epoch")
ax2.set_ylabel("Std")
ax2.legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt



loss = [
    28.35, 18.18, 14.09, 11.48, 9.56, 8.06, 6.85,
    5.84, 5.00, 4.28, 3.66, 3.12, 2.66, 2.25, 1.89, 1.57, 1.28,
    1.03, 0.80, 0.59, 0.40, 0.23, 0.08, -0.06, -0.19, -0.31, -0.42,
    -0.53, -0.62, -0.71, -0.79, -0.87, -0.94, -1.01, -1.07, -1.13, -1.18,
    -1.24, -1.28, -1.33, -1.37, -1.41, -1.45, -1.49, -1.53, -1.56, -1.59,
    -1.62, -1.65, -1.68, -1.70, -1.73, -1.75, -1.78, -1.80, -1.82, -1.84,
    -1.86, -1.88, -1.90, -1.92, -1.94, -1.95, -1.97, -1.99, -2.00, -2.02,
    -2.03, -2.05, -2.06, -2.08, -2.09, -2.10, -2.12, -2.13, -2.14, -2.15,
    -2.17, -2.18, -2.19, -2.20, -2.21, -2.22, -2.23, -2.24, -2.25, -2.26,
    -2.27, -2.28, -2.29, -2.30, -2.31, -2.32, -2.32, -2.33, -2.34, -2.35
]

pred_std_neuron = [
    2.02, 1.94, 1.90, 1.89, 1.88, 1.89, 1.90,
    1.91, 1.92, 1.94, 1.96, 1.99, 2.01, 2.03, 2.06, 2.08, 2.11,
    2.13, 2.15, 2.18, 2.20, 2.22, 2.25, 2.27, 2.29, 2.31, 2.34,
    2.36, 2.38, 2.40, 2.42, 2.44, 2.46, 2.48, 2.50, 2.52, 2.54,
    2.56, 2.58, 2.60, 2.62, 2.64, 2.65, 2.67, 2.69, 2.70, 2.72,
    2.74, 2.75, 2.77, 2.78, 2.80, 2.81, 2.83, 2.84, 2.85, 2.87,
    2.88, 2.90, 2.91, 2.92, 2.93, 2.95, 2.96, 2.97, 2.98, 3.00,
    3.01, 3.02, 3.03, 3.04, 3.05, 3.06, 3.07, 3.09, 3.10, 3.11,
    3.12, 3.13, 3.14, 3.15, 3.16, 3.17, 3.18, 3.19, 3.20, 3.21,
    3.22, 3.23, 3.23, 3.24, 3.25, 3.26, 3.27, 3.28, 3.29, 3.30
]
epochs = list(range(0, 1940, 20))

y_std = [6.73] * len(epochs)

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(8, 6), sharex=True)

ax1.plot(epochs, loss, marker='o')
ax1.set_ylabel("Loss")
ax1.set_title("Training Metrics (after removing readout normalization and initializing biases with mean true values)")

ax2.plot(epochs, pred_std_neuron, marker='o', label="pred_std")
ax2.plot(epochs, y_std, linestyle='--', label="y_std")
ax2.set_xlabel("Epoch")
ax2.set_ylabel("Std")
ax2.legend()

plt.tight_layout()
plt.show()

# %%
## Plot 2 neurons on top of each other
import matplotlib.pyplot as plt

def plot_neurons(n1, n2



epochs = list(range(0, 481, 20))
loss = [
    57.86, 71.10, 64.19, 54.65, 62.92, 47.24, 52.20, 53.59, 47.90, 101.51,
    70.26, 69.42, 38.65, 29.30, 126.05, 57.37, 57.75, 45.52, 45.84, 66.39,
    61.14, 43.35, 55.76, 52.79, 62.33
]
pred_std = [
    2.49, 5.24, 2.04, 2.11, 4.80, 4.12, 2.72, 2.46, 1.91, 6.11,
    4.79, 3.89, 0.00, 0.00, 8.71, 0.97, 0.57, 0.00, 0.58, 0.58,
    0.70, 0.01, 0.03, 0.61, 0.57
]
y_std = [
    7.33, 7.40, 7.42, 6.95, 6.49, 6.12, 6.61, 6.23, 6.18, 7.69,
    6.88, 6.77, 5.76, 5.01, 7.05, 7.05, 7.08, 6.14, 6.24, 7.46,
    7.19, 6.14, 6.84, 6.63, 7.40
]

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(8, 6), sharex=True)

ax1.plot(epochs, loss, marker='o')
ax1.set_ylabel("Loss")
ax1.set_title("Training Metrics (")

ax2.plot(epochs, pred_std, marker='o', label="pred_std")
ax2.plot(epochs, y_std, marker='o', label="y_std")
ax2.set_xlabel("Epoch")
ax2.set_ylabel("Std")
ax2.legend()

plt.tight_layout()
plt.show()
